# %%
from pyforbes import ForbesList
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
flist = ForbesList()
richest400_df = flist.get_df("billionaires", year =2022)

# %% [markdown]
# ### lets see how many years of data we have => we only have 1997 -> 2022 data

# %%
for i in range(1990,2022):
    try :
        flist.get_df("billionaires", year =i)
    except:
        print(i ," is missing")

# %% [markdown]
# ### number of billionaires through time

# %%
number_billionaires = []
for i in range(1997,2023):
    df = flist.get_df("billionaires", year =i)
    number_billionaires.append(df.shape[0])
plt.plot(np.arange(1997,2023),number_billionaires,label="Number of billionaires")
plt.axvline(x = 2020,color="red")

# %%
richest400_df.head()
# Out:
#            name  year  month              uri  rank       listUri  finalWorth  \
# 0  Billionaires  2022      4        elon-musk     1  billionaires    219000.0
# 1  Billionaires  2022      4       jeff-bezos     2  billionaires    171000.0
# 2  Billionaires  2022      4  bernard-arnault     3  billionaires    158000.0
# 3  Billionaires  2022      4       bill-gates     4  billionaires    129000.0
# 4  Billionaires  2022      4   warren-buffett     5  billionaires    118000.0
#
#                 category  otherCompensation  \
# 0             Automotive                  0
# 1             Technology                  0
# 2       Fashion & Retail                  0
# 3             Technology                  0
# 4  Finance & Investments                  0
#
#                                               person  ...  numberOfSiblings  \
# 0  {'name': 'Elon Musk', 'uri': 'elon-musk', 'ima...  ...               NaN
# 1  {'name': 'Jeff Bezos', 'uri': 'jeff-bezos', 'i...  ...               NaN
# 2  {'name': 'Bernard Arnault & family', 'uri': 'b...  ...               NaN
# 3  {'name': 'Bill Gates', 'uri': 'bill-gates', 'i...  ...               NaN
# 4  {'name': 'Warren Buffett', 'uri': 'warren-buff...  ...               NaN
#
#   numberOfSiblingsEst  bio notableDeal valueCreated primaryIndustry  \
# 0                 NaN  NaN         NaN          NaN             NaN
# 1                 NaN  NaN         NaN          NaN             NaN
# 2                 NaN  NaN         NaN          NaN             NaN
# 3                 NaN  NaN         NaN          NaN             NaN
# 4                 NaN  NaN         NaN          NaN             NaN
#
#   portraitImage landscapeImage recentEarnings assetsUnderManagement
# 0           NaN            NaN            NaN                   NaN
# 1           NaN            NaN            NaN                   NaN
# 2           NaN            NaN            NaN                   NaN
# 3           NaN            NaN            NaN                   NaN
# 4           NaN            NaN            NaN                   NaN
#
# [5 rows x 63 columns]

# %%
#checking if 
richest400_df.person[0]["name"]
# Out:
# 'Elon Musk'

# %%
richest400_df.to_csv('2022_data.csv', sep=',')

# %% [markdown]
# ### Creating the new name column because uri isn't the same as the Personname column from our original dataset

# %%
#we will use this function on every loaded dataset to have consistent names in each dataFrame 
def uri_to_name(data):
    lst = []
    for index, row in data.iterrows():
        lst.append(row['person']["name"])
    data.name = pd.Series(lst)
uri_to_name(richest400_df)
richest400_df.head()
# Out:
#                        name  year  month              uri  rank       listUri  \
# 0                 Elon Musk  2022      4        elon-musk     1  billionaires
# 1                Jeff Bezos  2022      4       jeff-bezos     2  billionaires
# 2  Bernard Arnault & family  2022      4  bernard-arnault     3  billionaires
# 3                Bill Gates  2022      4       bill-gates     4  billionaires
# 4            Warren Buffett  2022      4   warren-buffett     5  billionaires
#
#    finalWorth               category  otherCompensation  \
# 0    219000.0             Automotive                  0
# 1    171000.0             Technology                  0
# 2    158000.0       Fashion & Retail                  0
# 3    129000.0             Technology                  0
# 4    118000.0  Finance & Investments                  0
#
#                                               person  ...  numberOfSiblings  \
# 0  {'name': 'Elon Musk', 'uri': 'elon-musk', 'ima...  ...               NaN
# 1  {'name': 'Jeff Bezos', 'uri': 'jeff-bezos', 'i...  ...               NaN
# 2  {'name': 'Bernard Arnault & family', 'uri': 'b...  ...               NaN
# 3  {'name': 'Bill Gates', 'uri': 'bill-gates', 'i...  ...               NaN
# 4  {'name': 'Warren Buffett', 'uri': 'warren-buff...  ...               NaN
#
#   numberOfSiblingsEst  bio notableDeal valueCreated primaryIndustry  \
# 0                 NaN  NaN         NaN          NaN             NaN
# 1                 NaN  NaN         NaN          NaN             NaN
# 2                 NaN  NaN         NaN          NaN             NaN
# 3                 NaN  NaN         NaN          NaN             NaN
# 4                 NaN  NaN         NaN          NaN             NaN
#
#   portraitImage landscapeImage recentEarnings assetsUnderManagement
# 0           NaN            NaN            NaN                   NaN
# 1           NaN            NaN            NaN                   NaN
# 2           NaN            NaN            NaN                   NaN
# 3           NaN            NaN            NaN                   NaN
# 4           NaN            NaN            NaN                   NaN
#
# [5 rows x 63 columns]

# %% [markdown]
# ### testing if the column i created is exactly the same as the original data

# %%
original_data = pd.read_csv("forbes_2022_billionaires.csv")

# %%
#compares the two series
original_data.personName.compare(richest400_df.name)
# Out:
#                             self                      other
# 10         Gautam Adani & family               Gautam Adani
# 48                  He Xiangjian      He Xiangjian & family
# 49                Miriam Adelson    Miriam Adelson & family
# 87          Fan Hongwei & family                Fan Hongwei
# 154         Lin Jianhua & family                Lin Jianhua
# 178                    Xing Wang                  Wang Xing
# 188        Richard Qiangdong Liu                Richard Liu
# 192                  Shuirong Li                Li Shuirong
# 237                        Li Ge                      Ge Li
# 247   Paul Xiaoming Lee & family                   Paul Lee
# 341         Zhou Qunfei & family                Zhou Qunfei
# 438                Joshua Harris                Josh Harris
# 468                     Tse Ping          Tse Ping & family
# 590    Yeow Chor & Yeow Seng Lee  Lee Yeow Chor & Yeow Seng
# 635          Baoguo Zhu & family        Zhu Baoguo & family
# 689               Mong-Koo Chung             Chung Mong-Koo
# 775                    Yiling Wu                  Wu Yiling
# 958          Ernest Garcia, III.         Ernest Garcia, III
# 992                   Gaiteng Li                 Li Gaiteng
# 1040                  John Tyson        John Tyson & family
# 1070              Hamilton James    Hamilton James & family
# 1080           Shen Hua & family                   Hua Shen
# 2016            Zhen Li & family           Li Zhen & family
# 2193           Anant Asavabhokin         Anant Asavabhokhin
# 2232               David Hoffman             David Hoffmann
# 2273           P.V.Krishna Reddy         P.V. Krishna Reddy
# 2453          Casper Callerström         Caspar Callerström

# %% [markdown]
# ### I'll change the original column to the imported names since they are probably better formated

# %%
original_data["name"] = richest400_df.name
formatednames_data = original_data.drop("personName",axis=1)
formatednames_data.to_csv("forbes_2022_billionaires_goodnames.csv")

# %%
def get_rank_wealth(name,year): #gives the rank and the wealth of the billionaire a certain year
    df = flist.get_df("billionaires", year =year)
    uri_to_name(df)
    print(df.shape)
    if name in df.name.values:
        return int(df[df.name == name].finalWorth.index[0]+1),int(df[df.name == name].finalWorth.values[0]) #the +1 is used because we reccuperate the index of the sorted serie : the first is at index 0
    else:#if the name isnt in this year returns rank -1 and wealth 0
        return -1,0

get_rank_wealth("Elon Musk",2022)
# Out:
# (2668, 63)
# (1, 219000)

# %%
# Out:
# 5

# %%
def list_of_wealth(name,start=1997,stop=2022):
    rank_wealth = pd.DataFrame(columns=["rank","wealth"])

    for year in range(start,stop+1):
        print(year)
        rank,wealth = get_rank_wealth(name,year)
        rank_wealth = rank_wealth.append({'rank':rank,"wealth":wealth},ignore_index=True)
    
    return rank_wealth
    
elon=list_of_wealth("Elon Musk")
# Out:
# 1997
# (2, 39)
# 1998
# (1, 35)
# 1999
# (8, 46)
# 2000
# (8, 45)
# 2001
# (335, 73)
# 2002
# (333, 75)
# 2003
# (332, 77)
# 2004
# (432, 77)
# 2005
# (530, 77)
# 2006
# (628, 80)
# 2007
# (761, 84)
# 2008
# (908, 85)
# 2009
# (738, 83)
# 2010
# (1011, 65)
# 2011
# (1209, 65)
# 2012
# (1226, 67)
# 2013
# (1426, 67)
# 2014
# (1645, 68)
# 2015
# (1826, 66)
# 2016
# (1811, 69)
# 2017
# (2043, 70)
# 2018
# (2208, 71)
# 2019
# (2153, 71)
# 2020
# (2095, 63)
# 2021
# (2755, 64)
# 2022
# (2668, 63)

# %%
elon
# Out:
#    rank  wealth
# 0    -1       0
# 1    -1       0
# 2    -1       0
# 3    -1       0
# 4    -1       0
# 5    -1       0
# 6    -1       0
# 7    -1       0
# 8    -1       0
# 9    -1       0
# 10   -1       0
# 11   -1       0
# 12   -1       0
# 13   -1       0
# 14   -1       0
# 15  665    2000
# 16  547    2700
# 17  159    8400
# 18  101   12000
# 19   94   10700
# 20   80   13900
# 21   54   19900
# 22   40   22300
# 23   31   24600
# 24    2  151000
# 25    1  219000

# %% [markdown]
# ### NOT FINISHED i want to color each segment of the curve with the normalized value of there rank

# %%
norm = matplotlib.colors.Normalize(vmin=1.5, vmax=4.5)
ax.bar(df.x, df.y, color=cmap(norm(df.c.values)))
plt.plot(np.arange(1997,2023),elon.wealth,color=elon.rank)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16292\2614760819.py in <module>
# ----> 1 plt.plot(np.arange(1997,2023),elon.wealth,color=elon.rank)
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
# -> 2771         **({"data": data} if data is not None else {}), **kwargs)
#    2772
#    2773
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     368
#     369         self._color = None
# --> 370         self.set_color(color)
#     371         self._marker = MarkerStyle(marker, fillstyle)
#     372
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\lines.py in set_color(self, color)
#    1028         color : color
#    1029         """
# -> 1030         mcolors._check_color_like(color=color)
#    1031         self._color = color
#    1032         self.stale = True
#
# D:\Users\HP\anaconda3\lib\site-packages\matplotlib\colors.py in _check_color_like(**kwargs)
#     128     for k, v in kwargs.items():
#     129         if not is_color_like(v):
# --> 130             raise ValueError(f"{v!r} is not a valid value for {k}")
#     131
#     132
#
# ValueError: <bound method NDFrame.rank of    rank  wealth
# 0    -1       0
# 1    -1       0
# 2    -1       0
# 3    -1       0
# 4    -1       0
# 5    -1       0
# 6    -1       0
# 7    -1       0
# 8    -1       0
# 9    -1       0
# 10   -1       0
# 11   -1       0
# 12   -1       0
# 13   -1       0
# 14   -1       0
# 15  665    2000
# 16  547    2700
# 17  159    8400
# 18  101   12000
# 19   94   10700
# 20   80   13900
# 21   54   19900
# 22   40   22300
# 23   31   24600
# 24    2  151000
# 25    1  219000> is not a valid value for color

# %%
# Out:
# 1990  is missing
# 1991  is missing
# 1992  is missing
# 1993  is missing
# 1994  is missing
# 1995  is missing
# 1996  is missing
